# %% [markdown]
# # OpenStreetMap
# 作業內容：嘗試用 Overpass API ，在自己的 Juptyer Notebook 中，使用如 Folium 或是其他地圖套件載入你感興趣的商家或設施。
#
# ## 全台灣釣具行分佈

# %%
import requests
import json
import folium
import overpass

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# 您可以根據需求修改這裡的查詢條件
overpass_query = """
[out:json];
node
  ["shop"="fishing"]
  (21.8,119.5,25.4,122.0);
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
m = folium.Map(location=[23.7, 121.0], zoom_start=8)

# 遍歷 Overpass API 的回應資料，並將每個點標記在地圖上
for element in data['elements']:
    lat = element['lat']
    lon = element['lon']
    name = element.get('tags', {}).get('name', 'Fishing Port')
    
    folium.Marker(
        location=[lat, lon],
        popup=name,
        icon=folium.Icon(icon='info-sign')
    ).add_to(m)

# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d8c0a186b5603dacfb45dc68025310c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d8c0a186b5603dacfb45dc68025310c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d8c0a186b5603dacfb45dc68025310c = L.map(
#                 &quot;map_4d8c0a186b5603dacfb45dc68025310c&quot;,
#                 {
#                     center: [23.7, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2cfd3e3c13ada200ab7a497309dd0f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2cfd3e3c13ada200ab7a497309dd0f3.addTo(map_4d8c0a186b5603dacfb45dc68025310c);
#
#
#             var marker_5bba01913a2a84489eea452d68116384 = L.marker(
#                 [24.2616745, 120.8136783],
#                 {}
#             ).addTo(map_4d8c0a186b5603dacfb45dc68025310c);
#
#
#             var icon_2b78ae373b4b68d22e510c9995f07fd5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5bba01913a2a84489eea452d68116384.setIcon(icon_2b78ae373b4b68d22e510c9995f07fd5);
#
#
#         var popup_78e8e9dccf0d759d02fa77ad3886e05c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f878834b22da3b49a8c7531f894ccbb9 = $(`&lt;div id=&quot;html_f878834b22da3b49a8c7531f894ccbb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大統釣具店&lt;/div&gt;`)[0];
#                 popup_78e8e9dccf0d759d02fa77ad3886e05c.setContent(html_f878834b22da3b49a8c7531f894ccbb9);
#
#
#
#         marker_5bba01913a2a84489eea452d68116384.bindPopup(popup_78e8e9dccf0d759d02fa77ad3886e05c)
#         ;
#
#
#
#
#             var marker_52e4989eff2cd2483fe13962d327667a = L.marker(
#                 [22.6271435, 120.344182],
#                 {}
#             ).addTo(map_4d8c0a186b5603dacfb45dc68025310c);
#
#
#             var icon_7b19cccf93f4dc2c7d526d3394058c05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52e4989eff2cd2483fe13962d327667a.setIcon(icon_7b19cccf93f4dc2c7d526d3394058c05);
#
#
#         var popup_b7ef8efaa4addd80ab01976ee48b4e55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_600e0b8a37480693103497776a153d9f = $(`&lt;div id=&quot;html_600e0b8a37480693103497776a153d9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;魚拓釣具&lt;/div&gt;`)[0];
#                 popup_b7ef8efaa4addd80ab01976ee48b4e55.setContent(html_600e0b8a37480693103497776a153d9f);
#
#
#
#         marker_52e4989eff2cd2483fe13962d327667a.bindPopup(popup_b7ef8efaa4addd80ab01976ee48b4e55)
#         ;
#
#
#
#
#             var marker_9265109512aaefb6c28f6ad8acb5e6b9 = L.marker(
#                 [25.0195827, 121.4662673],
#                 {}
#             ).addTo(map_4d8c0a186b5603dacfb45dc68025310c);
#
#
#             var icon_e230c9abbd92ed29a48f2d0514cae62c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9265109512aaefb6c28f6ad8acb5e6b9.setIcon(icon_e230c9abbd92ed29a48f2d0514cae62c);
#
#
#         var popup_bc2485ec66e37490d0adecb04165754f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98badf3f35619d213c4bca084309347a = $(`&lt;div id=&quot;html_98badf3f35619d213c4bca084309347a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;永濱釣具行&lt;/div&gt;`)[0];
#                 popup_bc2485ec66e37490d0adecb04165754f.setContent(html_98badf3f35619d213c4bca084309347a);
#
#
#
#         marker_9265109512aaefb6c28f6ad8acb5e6b9.bindPopup(popup_bc2485ec66e37490d0adecb04165754f)
#         ;
#
#
#
#
#             var marker_99fc00b449d42796193372ece3c41772 = L.marker(
#                 [22.8079078, 120.2429556],
#                 {}
#             ).addTo(map_4d8c0a186b5603dacfb45dc68025310c);
#
#
#             var icon_47f8090f12380e905e6ef296211598c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &qu
